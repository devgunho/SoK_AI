# %% [markdown]
# # Sine wave
#
# x라는 값이 들어왔을 때 사인 함수의 결괏값인 y를 예측할 수 있는 모델을 학습
# <br/>
# ### Table of Contents
# - 데이터셋 구축
# - 모델 훈련
# - 성능 평가
# - 모델 변한
# - 추론
# - 바이너리 빌드
# - 배포

# %% [markdown]
# ### # Import dependencies

# %%
import tensorflow as tf
import numpy as np
import matplotlib as plt
from matplotlib import pyplot as pllt
import math

# %% [markdown]
# ### # Dataset

# %%
SAMPLES = 1000

SEED = 1337
np.random.seed(SEED)
tf.random.set_seed(SEED)

x_values = np.random.uniform(low=0, high=2 * math.pi, size=SAMPLES)

np.random.shuffle(x_values)

y_values = np.sin(x_values)

pllt.plot(x_values, y_values, 'b.')
pllt.show()
